# %%
import numpy as np
import pandas as pd
import csv
import glob

import matplotlib.pyplot as plt

from scipy.stats import kstest
from scipy.stats import normaltest
from scipy.stats import norm

from itertools import combinations
import pyvinecopulib as pv

import seaborn as sns
from scipy import stats

# %%
# Assuming you have three different CSV files with file paths
file1 = r'CompassPaper/HKNW.csv'
file2 = r'CompassPaper/FACT.csv'
file3 = r'CompassPaper/HRYR.csv'

# Read the three CSV files into separate dataframes
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
df3 = pd.read_csv(file3)

# Get the column names
NBO_dat = df1.dropna()
CT_dat = df2.dropna()
KGL_dat = df3.dropna()

NBO_dat = NBO_dat.drop(NBO_dat.columns[0], axis=1)
CT_dat = CT_dat.drop(CT_dat.columns[0], axis=1)
KGL_dat = KGL_dat.drop(KGL_dat.columns[0], axis=1)

# %%
KGL_dat_tmx = KGL_dat[['t_max_24']]
NBO_dat_tmx = NBO_dat[['t_max_24']]
CT_dat_tmx = CT_dat[['t_max_24']]

# %%
appended_df = pd.concat([KGL_dat_tmx, NBO_dat_tmx, CT_dat_tmx], axis=1)
appended_df
# Out:
#      t_max_24  t_max_24  t_max_24
# 0        22.0      23.0      22.0
# 1        25.0      25.0      30.0
# 2        24.0      26.0      29.0
# 3        25.0      26.0      30.0
# 4        27.0      26.0      24.0
# ..        ...       ...       ...
# 723      25.0      20.0      25.0
# 724      26.0      25.0      25.0
# 725      24.0      24.0      21.0
# 726      24.0      25.0      28.0
# 727      26.0      24.0      29.0
#
# [725 rows x 3 columns]

# %%
KGL_dat_tmx = KGL_dat_tmx.rename(columns={'t_max_24': 'col1'})
NBO_dat_tmx = NBO_dat_tmx.rename(columns={'t_max_24': 'col2'})
CT_dat_tmx = CT_dat_tmx.rename(columns={'t_max_24': 'col3'})

# %%
appended_df = pd.concat([KGL_dat_tmx, NBO_dat_tmx, CT_dat_tmx], axis=1)
appended_df
# Out:
#      col1  col2  col3
# 0    22.0  23.0  22.0
# 1    25.0  25.0  30.0
# 2    24.0  26.0  29.0
# 3    25.0  26.0  30.0
# 4    27.0  26.0  24.0
# ..    ...   ...   ...
# 723  25.0  20.0  25.0
# 724  26.0  25.0  25.0
# 725  24.0  24.0  21.0
# 726  24.0  25.0  28.0
# 727  26.0  24.0  29.0
#
# [725 rows x 3 columns]

# %%
column_names = KGL_dat.columns.tolist()
# Transform copula data using the empirical distribution    
KGL_data = pv.to_pseudo_obs(KGL_dat)
KGL_data = pd.DataFrame(KGL_data, columns= column_names)
KGL_data.to_csv("KGL_data_Emp.csv", index=False)

# %%
# appended_df.corr()

# %%
def process_dataset(dataset):
    # get the column names
    columns = dataset.columns

    # get the combinations of the columns
    comb = combinations(columns, 2)

    # List of copulas to test
    copulas = [pv.Bicop(pv.BicopFamily.gaussian), pv.Bicop(pv.BicopFamily.student),
               pv.Bicop(pv.BicopFamily.clayton), pv.Bicop(pv.BicopFamily.gumbel),
               pv.Bicop(pv.BicopFamily.frank)]

    # Create an empty dataframe to store the results
    result_df = pd.DataFrame(columns=["col1", "col2", "BIC", "LogLikelihood", "AIC", "Copula", "BicopFamily"])

    for cols in comb:
        col1, col2 = cols
        # select the columns
        X = pd.to_numeric(dataset[col1], errors='coerce')
        Y = pd.to_numeric(dataset[col2], errors='coerce')
        Z = np.array(list(zip(X, Y)))  # Convert to numpy array

        # Transform copula data using the empirical distribution
        u = pv.to_pseudo_obs(Z)

        # initialize the best BIC, loglikelihood, AIC, and copula
        best_bic = float("inf")
        best_loglik = -float("inf")
        best_aic = float("inf")
        best_copula = None

        for copula in copulas:
            copula.fit(data=u)
            loglik = copula.loglik(u)
            aic = copula.aic(u)

            if aic < best_aic:
                best_aic = aic
                best_bic = copula.bic(u)
                best_loglik = loglik
                best_copula = copula

        # print the results of the best copula
        print("Columns: ", cols)
        print("BIC: ", best_bic)
        print("LogLikelihood: ", best_loglik)
        print("AIC: ", best_aic)
        print("Copula: ", best_copula)
        print("BicopFamily: ", best_copula.family)

        # Append the results to the dataframe
        result_df = result_df.append({"col1": col1, "col2": col2, "BIC": best_bic, "LogLikelihood": best_loglik,
                                      "AIC": best_aic, "Copula": str(best_copula), "BicopFamily": best_copula.family},
                                     ignore_index=True)

    return result_df

# %%
datasets = [NBO_dat, CT_dat, KGL_dat]  
# datasets = appended_df
# Process each dataset and store the results
results = []
for idx, dataset in enumerate(datasets):
    result = process_dataset(dataset)
    results.append(result)

    # Save the results to a CSV file
    result.to_csv(f"result_dataset_{idx+1}.csv", index=False)

    print(f"Results for Dataset {idx+1} saved to result_dataset_{idx+1}.csv.")
    print()
# Out:
# Columns:  ('t_max_24', 't_min_24')
# BIC:  -132.20003724226922
# LogLikelihood:  69.37982623988123
# AIC:  -136.75965247976245
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = 2.9019
# BicopFamily:  BicopFamily.frank
# Columns:  ('t_max_24', 'td_mean_24')
# BIC:  -16.034781069923596
# LogLikelihood:  11.29719815370842
# AIC:  -20.59439630741684
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.182904
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('t_max_24', 'ws_mean_24')
# BIC:  -178.8132815134682
# LogLikelihood:  92.68644837548072
# AIC:  -183.37289675096144
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 0.779503
# BicopFamily:  BicopFamily.clayton
# Columns:  ('t_max_24', 'c_mean_24')
# BIC:  -410.8562998329997
# LogLikelihood:  208.70795753524646
# AIC:  -415.41591507049293
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.678036
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('t_max_24', 'rh_mean_day')
# BIC:  -607.9107371204245
# LogLikelihood:  307.2351761789589
# AIC:  -612.4703523579178
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.768635
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('t_max_24', 'p_max_24')
# BIC:  -270.5569349848499
# LogLikelihood:  138.55827511117155
# AIC:  -275.1165502223431
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.588453
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('t_max_24', 'p_min_24')
# BIC:  -478.4229955686224
# LogLikelihood:  242.49130540305782
# AIC:  -482.98261080611564
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.71733
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('t_min_24', 'td_mean_24')
# BIC:  -192.87777105096268
# LogLikelihood:  99.71869314422796
# AIC:  -197.4373862884559
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 0.828399
# BicopFamily:  BicopFamily.clayton
# Columns:  ('t_min_24', 'ws_mean_24')
# BIC:  -159.41117401182714
# LogLikelihood:  82.98539462466019
# AIC:  -163.97078924932038
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = 3.19161
# BicopFamily:  BicopFamily.frank
# Columns:  ('t_min_24', 'c_mean_24')
# BIC:  1.209238563633929
# LogLikelihood:  2.6751883369296565
# AIC:  -3.350376673859313
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -0.539172
# BicopFamily:  BicopFamily.frank
# Columns:  ('t_min_24', 'rh_mean_day')
# BIC:  -4.455548382693387
# LogLikelihood:  8.787389428839935
# AIC:  -13.57477885767987
# Copula:  <pyvinecopulib.Bicop>
# Student, parameters = -0.132144
#   9.07673
# BicopFamily:  BicopFamily.student
# Columns:  ('t_min_24', 'p_max_24')
# BIC:  -267.98936174939644
# LogLikelihood:  137.27448849344484
# AIC:  -272.54897698688967
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -4.2583
# BicopFamily:  BicopFamily.frank
# Columns:  ('t_min_24', 'p_min_24')
# BIC:  -250.82169287973375
# LogLikelihood:  128.6906540586135
# AIC:  -255.38130811722698
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -4.0836
# BicopFamily:  BicopFamily.frank
# Columns:  ('td_mean_24', 'ws_mean_24')
# BIC:  5.818280918867499
# LogLikelihood:  0.37066715931287125
# AIC:  1.2586656813742576
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.0329274
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('td_mean_24', 'c_mean_24')
# BIC:  -152.27259876566893
# LogLikelihood:  79.41610700158108
# AIC:  -156.83221400316216
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 0.677282
# BicopFamily:  BicopFamily.clayton
# Columns:  ('td_mean_24', 'rh_mean_day')
# BIC:  -420.34031733053354
# LogLikelihood:  213.44996628401339
# AIC:  -424.89993256802677
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = 0.67767
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('td_mean_24', 'p_max_24')
# BIC:  -68.01390776149826
# LogLikelihood:  37.28676149949575
# AIC:  -72.5735229989915
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -2.04588
# BicopFamily:  BicopFamily.frank
# Columns:  ('td_mean_24', 'p_min_24')
# BIC:  -28.114067878799283
# LogLikelihood:  17.33684155814626
# AIC:  -32.67368311629252
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -1.34261
# BicopFamily:  BicopFamily.frank
# Columns:  ('ws_mean_24', 'c_mean_24')
# BIC:  -102.21269067363103
# LogLikelihood:  54.38615295556214
# AIC:  -106.77230591112428
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -2.4375
# BicopFamily:  BicopFamily.frank
# Columns:  ('ws_mean_24', 'rh_mean_day')
# BIC:  -140.96142001245656
# LogLikelihood:  73.7605176249749
# AIC:  -145.5210352499498
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -2.92075
# BicopFamily:  BicopFamily.frank
# Columns:  ('ws_mean_24', 'p_max_24')
# BIC:  -80.64945080532517
# LogLikelihood:  43.60453302140921
# AIC:  -85.20906604281842
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -2.19878
# BicopFamily:  BicopFamily.frank
# Columns:  ('ws_mean_24', 'p_min_24')
# BIC:  -119.41653064678707
# LogLikelihood:  62.98807294214016
# AIC:  -123.97614588428031
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -2.66985
# BicopFamily:  BicopFamily.frank
# Columns:  ('c_mean_24', 'rh_mean_day')
# BIC:  -499.03576560284984
# LogLikelihood:  252.79769042017153
# AIC:  -503.59538084034307
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = 0.720549
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('c_mean_24', 'p_max_24')
# BIC:  -91.08470816902539
# LogLikelihood:  48.82216170325932
# AIC:  -95.64432340651864
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = 0.375598
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('c_mean_24', 'p_min_24')
# BIC:  -136.7023247202346
# LogLikelihood:  71.63096997886392
# AIC:  -141.26193995772783
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = 0.442259
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('rh_mean_day', 'p_max_24')
# BIC:  -60.12273414719595
# LogLikelihood:  33.341174692344595
# AIC:  -64.68234938468919
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 0.41746
# BicopFamily:  BicopFamily.clayton
# Columns:  ('rh_mean_day', 'p_min_24')
# BIC:  -120.72698768272484
# LogLikelihood:  63.64330146010904
# AIC:  -125.28660292021809
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = 0.417368
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('p_max_24', 'p_min_24')
# BIC:  -1028.7084874063319
# LogLikelihood:  520.9138589406592
# AIC:  -1037.8277178813184
# Copula:  <pyvinecopulib.Bicop>
# Student, parameters = 0.887349
#  10.4101
# BicopFamily:  BicopFamily.student
# Results for Dataset 1 saved to result_dataset_1.csv.
#
# Columns:  ('t_max_24', 't_min_24')
# BIC:  -348.5365100260527
# LogLikelihood:  177.5613408404537
# AIC:  -353.1226816809074
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = 4.88688
# BicopFamily:  BicopFamily.frank
# Columns:  ('t_max_24', 'td_mean_24')
# BIC:  -223.95230239827623
# LogLikelihood:  115.26923702656545
# AIC:  -228.5384740531309
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = 3.80442
# BicopFamily:  BicopFamily.frank
# Columns:  ('t_max_24', 'ws_mean_24')
# BIC:  -1.220518971447322
# LogLikelihood:  3.9033453131509983
# AIC:  -5.806690626301997
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 0.122796
# BicopFamily:  BicopFamily.clayton
# Columns:  ('t_max_24', 'c_mean_24')
# BIC:  -261.3081508757176
# LogLikelihood:  137.24024709271347
# AIC:  -270.48049418542695
# Copula:  <pyvinecopulib.Bicop>
# Student, parameters = -0.583872
#   15.7221
# BicopFamily:  BicopFamily.student
# Columns:  ('t_max_24', 'rh_mean_day')
# BIC:  -335.16624941766537
# LogLikelihood:  170.87621053626003
# AIC:  -339.75242107252006
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.619468
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('t_max_24', 'p_max_24')
# BIC:  -285.9104108320971
# LogLikelihood:  146.2482912434759
# AIC:  -290.4965824869518
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -4.34842
# BicopFamily:  BicopFamily.frank
# Columns:  ('t_max_24', 'p_min_24')
# BIC:  -184.08717715577734
# LogLikelihood:  95.336674405316
# AIC:  -188.673348810632
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -3.39445
# BicopFamily:  BicopFamily.frank
# Columns:  ('t_min_24', 'td_mean_24')
# BIC:  -793.6548353390106
# LogLikelihood:  403.41358932436
# AIC:  -802.82717864872
# Copula:  <pyvinecopulib.Bicop>
# Student, parameters = 0.824452
#  11.7472
# BicopFamily:  BicopFamily.student
# Columns:  ('t_min_24', 'ws_mean_24')
# BIC:  -267.4265177288124
# LogLikelihood:  137.00634469183356
# AIC:  -272.0126893836671
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = 0.568225
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('t_min_24', 'c_mean_24')
# BIC:  -8.5352516970162
# LogLikelihood:  7.560711675935437
# AIC:  -13.121423351870874
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 0.184276
# BicopFamily:  BicopFamily.clayton
# Columns:  ('t_min_24', 'rh_mean_day')
# BIC:  -26.081442466982217
# LogLikelihood:  16.333807060918446
# AIC:  -30.66761412183689
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -1.26116
# BicopFamily:  BicopFamily.frank
# Columns:  ('t_min_24', 'p_max_24')
# BIC:  -484.60723936475927
# LogLikelihood:  245.59670550980698
# AIC:  -489.19341101961396
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -6.02092
# BicopFamily:  BicopFamily.frank
# Columns:  ('t_min_24', 'p_min_24')
# BIC:  -294.27343452598615
# LogLikelihood:  150.42980309042042
# AIC:  -298.85960618084084
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -4.38402
# BicopFamily:  BicopFamily.frank
# Columns:  ('td_mean_24', 'ws_mean_24')
# BIC:  -88.3580942695557
# LogLikelihood:  47.472132962205194
# AIC:  -92.94426592441039
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 0.493432
# BicopFamily:  BicopFamily.clayton
# Columns:  ('td_mean_24', 'c_mean_24')
# BIC:  -23.69226445136849
# LogLikelihood:  15.139218053111582
# AIC:  -28.278436106223165
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 0.278718
# BicopFamily:  BicopFamily.clayton
# Columns:  ('td_mean_24', 'rh_mean_day')
# BIC:  -64.3613480023029
# LogLikelihood:  35.47375982857879
# AIC:  -68.94751965715759
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 0.380369
# BicopFamily:  BicopFamily.clayton
# Columns:  ('td_mean_24', 'p_max_24')
# BIC:  -459.0526085246055
# LogLikelihood:  232.8193900897301
# AIC:  -463.6387801794602
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -5.83534
# BicopFamily:  BicopFamily.frank
# Columns:  ('td_mean_24', 'p_min_24')
# BIC:  -272.6271730024715
# LogLikelihood:  139.6066723286631
# AIC:  -277.2133446573262
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -4.19744
# BicopFamily:  BicopFamily.frank
# Columns:  ('ws_mean_24', 'c_mean_24')
# BIC:  -43.813799971757724
# LogLikelihood:  25.1999858133062
# AIC:  -48.3999716266124
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 0.380317
# BicopFamily:  BicopFamily.clayton
# Columns:  ('ws_mean_24', 'rh_mean_day')
# BIC:  1.1877387802337118
# LogLikelihood:  2.6992164373104814
# AIC:  -3.398432874620963
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -0.525239
# BicopFamily:  BicopFamily.frank
# Columns:  ('ws_mean_24', 'p_max_24')
# BIC:  -99.62336200764003
# LogLikelihood:  53.10476683124735
# AIC:  -104.2095336624947
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -2.36238
# BicopFamily:  BicopFamily.frank
# Columns:  ('ws_mean_24', 'p_min_24')
# BIC:  -81.84741979758748
# LogLikelihood:  44.21679572622108
# AIC:  -86.43359145244216
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -2.14066
# BicopFamily:  BicopFamily.frank
# Columns:  ('c_mean_24', 'rh_mean_day')
# BIC:  -356.99720009686513
# LogLikelihood:  181.7916858758599
# AIC:  -361.5833717517198
# Copula:  <pyvinecopulib.Bicop>
# Gumbel, parameters = 1.72538
# BicopFamily:  BicopFamily.gumbel
# Columns:  ('c_mean_24', 'p_max_24')
# BIC:  10.020764475130223
# LogLikelihood:  1.5757894172895632
# AIC:  0.8484211654208735
# Copula:  <pyvinecopulib.Bicop>
# Student, parameters = -0.0132638
#    11.1148
# BicopFamily:  BicopFamily.student
# Columns:  ('c_mean_24', 'p_min_24')
# BIC:  -7.178905241553812
# LogLikelihood:  10.17562427563158
# AIC:  -16.35124855126316
# Copula:  <pyvinecopulib.Bicop>
# Student, parameters = -0.072883
#   5.24386
# BicopFamily:  BicopFamily.student
# Columns:  ('rh_mean_day', 'p_max_24')
# BIC:  -4.286992610445192
# LogLikelihood:  5.436582132649933
# AIC:  -8.873164265299867
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = 0.734011
# BicopFamily:  BicopFamily.frank
# Columns:  ('rh_mean_day', 'p_min_24')
# BIC:  -0.7636197418809552
# LogLikelihood:  3.674895698367815
# AIC:  -5.34979139673563
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = 0.61403
# BicopFamily:  BicopFamily.frank
# Columns:  ('p_max_24', 'p_min_24')
# BIC:  -1155.0201879985748
# LogLikelihood:  584.096265654142
# AIC:  -1164.192531308284
# Copula:  <pyvinecopulib.Bicop>
# Student, parameters = 0.895699
#  4.98652
# BicopFamily:  BicopFamily.student
# Results for Dataset 2 saved to result_dataset_2.csv.
#
# Columns:  ('t_max_24', 't_min_24')
# BIC:  -5.637018201660958
# LogLikelihood:  6.102548056536467
# AIC:  -10.205096113072933
# Copula:  <pyvinecopulib.Bicop>
# Gumbel, parameters = 1.08874
# BicopFamily:  BicopFamily.gumbel
# Columns:  ('t_max_24', 'td_mean_24')
# BIC:  -143.82862152038587
# LogLikelihood:  75.19834971589893
# AIC:  -148.39669943179786
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.448598
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('t_max_24', 'ws_mean_24')
# BIC:  -82.41430544642061
# LogLikelihood:  47.77523063462228
# AIC:  -91.55046126924456
# Copula:  <pyvinecopulib.Bicop>
# Student, parameters = 0.333629
#  6.08516
# BicopFamily:  BicopFamily.student
# Columns:  ('t_max_24', 'c_mean_24')
# BIC:  -236.43910676772515
# LogLikelihood:  121.50359233956856
# AIC:  -241.0071846791371
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -3.88044
# BicopFamily:  BicopFamily.frank
# Columns:  ('t_max_24', 'rh_mean_day')
# BIC:  -438.30678899601855
# LogLikelihood:  225.72147240942124
# AIC:  -447.4429448188425
# Copula:  <pyvinecopulib.Bicop>
# Student, parameters = -0.691941
#   13.3594
# BicopFamily:  BicopFamily.student
# Columns:  ('t_max_24', 'p_max_24')
# BIC:  -29.210102670283945
# LogLikelihood:  17.88909029084796
# AIC:  -33.77818058169592
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -1.41517
# BicopFamily:  BicopFamily.frank
# Columns:  ('t_max_24', 'p_min_24')
# BIC:  -113.12492440591356
# LogLikelihood:  59.84650115866277
# AIC:  -117.69300231732554
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.413705
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('t_min_24', 'td_mean_24')
# BIC:  -14.352622622948235
# LogLikelihood:  10.460350267180106
# AIC:  -18.92070053436021
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 0.214731
# BicopFamily:  BicopFamily.clayton
# Columns:  ('t_min_24', 'ws_mean_24')
# BIC:  -2.520161928443354
# LogLikelihood:  4.544119919927665
# AIC:  -7.08823983985533
# Copula:  <pyvinecopulib.Bicop>
# Gumbel, parameters = 1.07926
# BicopFamily:  BicopFamily.gumbel
# Columns:  ('t_min_24', 'c_mean_24')
# BIC:  -30.934517036230105
# LogLikelihood:  18.75129747382104
# AIC:  -35.50259494764208
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 0.299523
# BicopFamily:  BicopFamily.clayton
# Columns:  ('t_min_24', 'rh_mean_day')
# BIC:  4.664766208383596
# LogLikelihood:  0.9516558515141899
# AIC:  0.09668829697162029
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 0.0566663
# BicopFamily:  BicopFamily.clayton
# Columns:  ('t_min_24', 'p_max_24')
# BIC:  1.5120494183485587
# LogLikelihood:  5.8120532022376965
# AIC:  -7.624106404475393
# Copula:  <pyvinecopulib.Bicop>
# Student, parameters = -0.107143
#   7.52116
# BicopFamily:  BicopFamily.student
# Columns:  ('t_min_24', 'p_min_24')
# BIC:  1.231702268222465
# LogLikelihood:  5.952226777300743
# AIC:  -7.904453554601487
# Copula:  <pyvinecopulib.Bicop>
# Student, parameters = -0.0256852
#    5.34441
# BicopFamily:  BicopFamily.student
# Columns:  ('td_mean_24', 'ws_mean_24')
# BIC:  -83.66930103878055
# LogLikelihood:  45.11868947509626
# AIC:  -88.23737895019252
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.349404
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('td_mean_24', 'c_mean_24')
# BIC:  -445.259498912639
# LogLikelihood:  225.9137884120255
# AIC:  -449.827576824051
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 1.49881
# BicopFamily:  BicopFamily.clayton
# Columns:  ('td_mean_24', 'rh_mean_day')
# BIC:  -1107.6360228348603
# LogLikelihood:  557.1020503731362
# AIC:  -1112.2041007462724
# Copula:  <pyvinecopulib.Bicop>
# Clayton, parameters = 3.86031
# BicopFamily:  BicopFamily.clayton
# Columns:  ('td_mean_24', 'p_max_24')
# BIC:  -64.0892102505554
# LogLikelihood:  35.328644080983686
# AIC:  -68.65728816196737
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -1.98164
# BicopFamily:  BicopFamily.frank
# Columns:  ('td_mean_24', 'p_min_24')
# BIC:  -44.88613224240935
# LogLikelihood:  25.727105076910664
# AIC:  -49.45421015382133
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.274373
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('ws_mean_24', 'c_mean_24')
# BIC:  -11.196060214264016
# LogLikelihood:  8.882069062837996
# AIC:  -15.764138125675991
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.15942
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('ws_mean_24', 'rh_mean_day')
# BIC:  -79.59769553150032
# LogLikelihood:  43.08288672145615
# AIC:  -84.1657734429123
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.341952
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('ws_mean_24', 'p_max_24')
# BIC:  2.689461275973688
# LogLikelihood:  1.939308317719144
# AIC:  -1.8786166354382878
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -0.452008
# BicopFamily:  BicopFamily.frank
# Columns:  ('ws_mean_24', 'p_min_24')
# BIC:  -2.2874341491652235
# LogLikelihood:  4.4277560302886
# AIC:  -6.855512060577199
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.116128
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('c_mean_24', 'rh_mean_day')
# BIC:  -591.9091261394733
# LogLikelihood:  299.2386020254426
# AIC:  -596.4772040508852
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = 0.757322
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('c_mean_24', 'p_max_24')
# BIC:  -3.683825264096468
# LogLikelihood:  5.125951587754222
# AIC:  -8.251903175508444
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.125391
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('c_mean_24', 'p_min_24')
# BIC:  5.219864533392091
# LogLikelihood:  0.6741066890099425
# AIC:  0.6517866219801149
# Copula:  <pyvinecopulib.Bicop>
# Gaussian, parameters = -0.0454821
# BicopFamily:  BicopFamily.gaussian
# Columns:  ('rh_mean_day', 'p_max_24')
# BIC:  -24.42727176098845
# LogLikelihood:  15.497674836200213
# AIC:  -28.995349672400426
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -1.3014
# BicopFamily:  BicopFamily.frank
# Columns:  ('rh_mean_day', 'p_min_24')
# BIC:  -1.6294546232544374
# LogLikelihood:  4.098766267333207
# AIC:  -6.197532534666413
# Copula:  <pyvinecopulib.Bicop>
# Frank, parameters = -0.655809
# BicopFamily:  BicopFamily.frank
# Columns:  ('p_max_24', 'p_min_24')
# BIC:  -865.7353847296189
# LogLikelihood:  439.43577027622143
# AIC:  -874.8715405524429
# Copula:  <pyvinecopulib.Bicop>
# Student, parameters = 0.849759
#  5.03803
# BicopFamily:  BicopFamily.student
# Results for Dataset 3 saved to result_dataset_3.csv.

# %%
# Print or further process the results as needed
for idx, result in enumerate(results):
    print(f"Results for Dataset {idx+1}:")
    print(result)
# Out:
# Results for Dataset 1:
#            col1         col2          BIC  LogLikelihood          AIC  \
# 0      t_max_24     t_min_24  -132.200037      69.379826  -136.759652
# 1      t_max_24   td_mean_24   -16.034781      11.297198   -20.594396
# 2      t_max_24   ws_mean_24  -178.813282      92.686448  -183.372897
# 3      t_max_24    c_mean_24  -410.856300     208.707958  -415.415915
# 4      t_max_24  rh_mean_day  -607.910737     307.235176  -612.470352
# 5      t_max_24     p_max_24  -270.556935     138.558275  -275.116550
# 6      t_max_24     p_min_24  -478.422996     242.491305  -482.982611
# 7      t_min_24   td_mean_24  -192.877771      99.718693  -197.437386
# 8      t_min_24   ws_mean_24  -159.411174      82.985395  -163.970789
# 9      t_min_24    c_mean_24     1.209239       2.675188    -3.350377
# 10     t_min_24  rh_mean_day    -4.455548       8.787389   -13.574779
# 11     t_min_24     p_max_24  -267.989362     137.274488  -272.548977
# 12     t_min_24     p_min_24  -250.821693     128.690654  -255.381308
# 13   td_mean_24   ws_mean_24     5.818281       0.370667     1.258666
# 14   td_mean_24    c_mean_24  -152.272599      79.416107  -156.832214
# 15   td_mean_24  rh_mean_day  -420.340317     213.449966  -424.899933
# 16   td_mean_24     p_max_24   -68.013908      37.286761   -72.573523
# 17   td_mean_24     p_min_24   -28.114068      17.336842   -32.673683
# 18   ws_mean_24    c_mean_24  -102.212691      54.386153  -106.772306
# 19   ws_mean_24  rh_mean_day  -140.961420      73.760518  -145.521035
# 20   ws_mean_24     p_max_24   -80.649451      43.604533   -85.209066
# 21   ws_mean_24     p_min_24  -119.416531      62.988073  -123.976146
# 22    c_mean_24  rh_mean_day  -499.035766     252.797690  -503.595381
# 23    c_mean_24     p_max_24   -91.084708      48.822162   -95.644323
# 24    c_mean_24     p_min_24  -136.702325      71.630970  -141.261940
# 25  rh_mean_day     p_max_24   -60.122734      33.341175   -64.682349
# 26  rh_mean_day     p_min_24  -120.726988      63.643301  -125.286603
# 27     p_max_24     p_min_24 -1028.708487     520.913859 -1037.827718
#
#                                                Copula           BicopFamily
# 0   <pyvinecopulib.Bicop>\nFrank, parameters = 2.9019     BicopFamily.frank
# 1   <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 2   <pyvinecopulib.Bicop>\nClayton, parameters = 0...   BicopFamily.clayton
# 3   <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 4   <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 5   <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 6   <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 7   <pyvinecopulib.Bicop>\nClayton, parameters = 0...   BicopFamily.clayton
# 8   <pyvinecopulib.Bicop>\nFrank, parameters = 3.1...     BicopFamily.frank
# 9   <pyvinecopulib.Bicop>\nFrank, parameters = -0....     BicopFamily.frank
# 10  <pyvinecopulib.Bicop>\nStudent, parameters = -...   BicopFamily.student
# 11  <pyvinecopulib.Bicop>\nFrank, parameters = -4....     BicopFamily.frank
# 12  <pyvinecopulib.Bicop>\nFrank, parameters = -4....     BicopFamily.frank
# 13  <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 14  <pyvinecopulib.Bicop>\nClayton, parameters = 0...   BicopFamily.clayton
# 15  <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 16  <pyvinecopulib.Bicop>\nFrank, parameters = -2....     BicopFamily.frank
# 17  <pyvinecopulib.Bicop>\nFrank, parameters = -1....     BicopFamily.frank
# 18  <pyvinecopulib.Bicop>\nFrank, parameters = -2....     BicopFamily.frank
# 19  <pyvinecopulib.Bicop>\nFrank, parameters = -2....     BicopFamily.frank
# 20  <pyvinecopulib.Bicop>\nFrank, parameters = -2....     BicopFamily.frank
# 21  <pyvinecopulib.Bicop>\nFrank, parameters = -2....     BicopFamily.frank
# 22  <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 23  <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 24  <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 25  <pyvinecopulib.Bicop>\nClayton, parameters = 0...   BicopFamily.clayton
# 26  <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 27  <pyvinecopulib.Bicop>\nStudent, parameters = 0...   BicopFamily.student
# Results for Dataset 2:
#            col1         col2          BIC  LogLikelihood          AIC  \
# 0      t_max_24     t_min_24  -348.536510     177.561341  -353.122682
# 1      t_max_24   td_mean_24  -223.952302     115.269237  -228.538474
# 2      t_max_24   ws_mean_24    -1.220519       3.903345    -5.806691
# 3      t_max_24    c_mean_24  -261.308151     137.240247  -270.480494
# 4      t_max_24  rh_mean_day  -335.166249     170.876211  -339.752421
# 5      t_max_24     p_max_24  -285.910411     146.248291  -290.496582
# 6      t_max_24     p_min_24  -184.087177      95.336674  -188.673349
# 7      t_min_24   td_mean_24  -793.654835     403.413589  -802.827179
# 8      t_min_24   ws_mean_24  -267.426518     137.006345  -272.012689
# 9      t_min_24    c_mean_24    -8.535252       7.560712   -13.121423
# 10     t_min_24  rh_mean_day   -26.081442      16.333807   -30.667614
# 11     t_min_24     p_max_24  -484.607239     245.596706  -489.193411
# 12     t_min_24     p_min_24  -294.273435     150.429803  -298.859606
# 13   td_mean_24   ws_mean_24   -88.358094      47.472133   -92.944266
# 14   td_mean_24    c_mean_24   -23.692264      15.139218   -28.278436
# 15   td_mean_24  rh_mean_day   -64.361348      35.473760   -68.947520
# 16   td_mean_24     p_max_24  -459.052609     232.819390  -463.638780
# 17   td_mean_24     p_min_24  -272.627173     139.606672  -277.213345
# 18   ws_mean_24    c_mean_24   -43.813800      25.199986   -48.399972
# 19   ws_mean_24  rh_mean_day     1.187739       2.699216    -3.398433
# 20   ws_mean_24     p_max_24   -99.623362      53.104767  -104.209534
# 21   ws_mean_24     p_min_24   -81.847420      44.216796   -86.433591
# 22    c_mean_24  rh_mean_day  -356.997200     181.791686  -361.583372
# 23    c_mean_24     p_max_24    10.020764       1.575789     0.848421
# 24    c_mean_24     p_min_24    -7.178905      10.175624   -16.351249
# 25  rh_mean_day     p_max_24    -4.286993       5.436582    -8.873164
# 26  rh_mean_day     p_min_24    -0.763620       3.674896    -5.349791
# 27     p_max_24     p_min_24 -1155.020188     584.096266 -1164.192531
#
#                                                Copula           BicopFamily
# 0   <pyvinecopulib.Bicop>\nFrank, parameters = 4.8...     BicopFamily.frank
# 1   <pyvinecopulib.Bicop>\nFrank, parameters = 3.8...     BicopFamily.frank
# 2   <pyvinecopulib.Bicop>\nClayton, parameters = 0...   BicopFamily.clayton
# 3   <pyvinecopulib.Bicop>\nStudent, parameters = -...   BicopFamily.student
# 4   <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 5   <pyvinecopulib.Bicop>\nFrank, parameters = -4....     BicopFamily.frank
# 6   <pyvinecopulib.Bicop>\nFrank, parameters = -3....     BicopFamily.frank
# 7   <pyvinecopulib.Bicop>\nStudent, parameters = 0...   BicopFamily.student
# 8   <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 9   <pyvinecopulib.Bicop>\nClayton, parameters = 0...   BicopFamily.clayton
# 10  <pyvinecopulib.Bicop>\nFrank, parameters = -1....     BicopFamily.frank
# 11  <pyvinecopulib.Bicop>\nFrank, parameters = -6....     BicopFamily.frank
# 12  <pyvinecopulib.Bicop>\nFrank, parameters = -4....     BicopFamily.frank
# 13  <pyvinecopulib.Bicop>\nClayton, parameters = 0...   BicopFamily.clayton
# 14  <pyvinecopulib.Bicop>\nClayton, parameters = 0...   BicopFamily.clayton
# 15  <pyvinecopulib.Bicop>\nClayton, parameters = 0...   BicopFamily.clayton
# 16  <pyvinecopulib.Bicop>\nFrank, parameters = -5....     BicopFamily.frank
# 17  <pyvinecopulib.Bicop>\nFrank, parameters = -4....     BicopFamily.frank
# 18  <pyvinecopulib.Bicop>\nClayton, parameters = 0...   BicopFamily.clayton
# 19  <pyvinecopulib.Bicop>\nFrank, parameters = -0....     BicopFamily.frank
# 20  <pyvinecopulib.Bicop>\nFrank, parameters = -2....     BicopFamily.frank
# 21  <pyvinecopulib.Bicop>\nFrank, parameters = -2....     BicopFamily.frank
# 22  <pyvinecopulib.Bicop>\nGumbel, parameters = 1....    BicopFamily.gumbel
# 23  <pyvinecopulib.Bicop>\nStudent, parameters = -...   BicopFamily.student
# 24  <pyvinecopulib.Bicop>\nStudent, parameters = -...   BicopFamily.student
# 25  <pyvinecopulib.Bicop>\nFrank, parameters = 0.7...     BicopFamily.frank
# 26  <pyvinecopulib.Bicop>\nFrank, parameters = 0.6...     BicopFamily.frank
# 27  <pyvinecopulib.Bicop>\nStudent, parameters = 0...   BicopFamily.student
# Results for Dataset 3:
#            col1         col2          BIC  LogLikelihood          AIC  \
# 0      t_max_24     t_min_24    -5.637018       6.102548   -10.205096
# 1      t_max_24   td_mean_24  -143.828622      75.198350  -148.396699
# 2      t_max_24   ws_mean_24   -82.414305      47.775231   -91.550461
# 3      t_max_24    c_mean_24  -236.439107     121.503592  -241.007185
# 4      t_max_24  rh_mean_day  -438.306789     225.721472  -447.442945
# 5      t_max_24     p_max_24   -29.210103      17.889090   -33.778181
# 6      t_max_24     p_min_24  -113.124924      59.846501  -117.693002
# 7      t_min_24   td_mean_24   -14.352623      10.460350   -18.920701
# 8      t_min_24   ws_mean_24    -2.520162       4.544120    -7.088240
# 9      t_min_24    c_mean_24   -30.934517      18.751297   -35.502595
# 10     t_min_24  rh_mean_day     4.664766       0.951656     0.096688
# 11     t_min_24     p_max_24     1.512049       5.812053    -7.624106
# 12     t_min_24     p_min_24     1.231702       5.952227    -7.904454
# 13   td_mean_24   ws_mean_24   -83.669301      45.118689   -88.237379
# 14   td_mean_24    c_mean_24  -445.259499     225.913788  -449.827577
# 15   td_mean_24  rh_mean_day -1107.636023     557.102050 -1112.204101
# 16   td_mean_24     p_max_24   -64.089210      35.328644   -68.657288
# 17   td_mean_24     p_min_24   -44.886132      25.727105   -49.454210
# 18   ws_mean_24    c_mean_24   -11.196060       8.882069   -15.764138
# 19   ws_mean_24  rh_mean_day   -79.597696      43.082887   -84.165773
# 20   ws_mean_24     p_max_24     2.689461       1.939308    -1.878617
# 21   ws_mean_24     p_min_24    -2.287434       4.427756    -6.855512
# 22    c_mean_24  rh_mean_day  -591.909126     299.238602  -596.477204
# 23    c_mean_24     p_max_24    -3.683825       5.125952    -8.251903
# 24    c_mean_24     p_min_24     5.219865       0.674107     0.651787
# 25  rh_mean_day     p_max_24   -24.427272      15.497675   -28.995350
# 26  rh_mean_day     p_min_24    -1.629455       4.098766    -6.197533
# 27     p_max_24     p_min_24  -865.735385     439.435770  -874.871541
#
#                                                Copula           BicopFamily
# 0   <pyvinecopulib.Bicop>\nGumbel, parameters = 1....    BicopFamily.gumbel
# 1   <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 2   <pyvinecopulib.Bicop>\nStudent, parameters = 0...   BicopFamily.student
# 3   <pyvinecopulib.Bicop>\nFrank, parameters = -3....     BicopFamily.frank
# 4   <pyvinecopulib.Bicop>\nStudent, parameters = -...   BicopFamily.student
# 5   <pyvinecopulib.Bicop>\nFrank, parameters = -1....     BicopFamily.frank
# 6   <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 7   <pyvinecopulib.Bicop>\nClayton, parameters = 0...   BicopFamily.clayton
# 8   <pyvinecopulib.Bicop>\nGumbel, parameters = 1....    BicopFamily.gumbel
# 9   <pyvinecopulib.Bicop>\nClayton, parameters = 0...   BicopFamily.clayton
# 10  <pyvinecopulib.Bicop>\nClayton, parameters = 0...   BicopFamily.clayton
# 11  <pyvinecopulib.Bicop>\nStudent, parameters = -...   BicopFamily.student
# 12  <pyvinecopulib.Bicop>\nStudent, parameters = -...   BicopFamily.student
# 13  <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 14  <pyvinecopulib.Bicop>\nClayton, parameters = 1...   BicopFamily.clayton
# 15  <pyvinecopulib.Bicop>\nClayton, parameters = 3...   BicopFamily.clayton
# 16  <pyvinecopulib.Bicop>\nFrank, parameters = -1....     BicopFamily.frank
# 17  <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 18  <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 19  <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 20  <pyvinecopulib.Bicop>\nFrank, parameters = -0....     BicopFamily.frank
# 21  <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 22  <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 23  <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 24  <pyvinecopulib.Bicop>\nGaussian, parameters = ...  BicopFamily.gaussian
# 25  <pyvinecopulib.Bicop>\nFrank, parameters = -1....     BicopFamily.frank
# 26  <pyvinecopulib.Bicop>\nFrank, parameters = -0....     BicopFamily.frank
# 27  <pyvinecopulib.Bicop>\nStudent, parameters = 0...   BicopFamily.student
